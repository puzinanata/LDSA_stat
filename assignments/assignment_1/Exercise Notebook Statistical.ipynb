# %% [markdown]
# # Descriptive Statistics Exercises

# %%
import pandas as pd

# %% [markdown]
# ## Data Description
#
# | Variable    | Description                                                                                                                                          |
# | ----------- | ---------------------------------------------------------------------------------------------------------------------------------------------------- |
# | minority    | Does the instructor belong to a minority (non-Caucasian) group?                                                                                      |
# | age         | The professor's age                                                                                                                                  |
# | gender      | Indicating whether the instructor was male or female.                                                                                                |
# | credits     | Is the course a single-credit elective?                                                                                                              |
# | beauty      | Rating of the instructor's physical appearance by a panel of six students averaged across the six panelists and standardized to have a mean of zero. |
# | eval        | Course overall teaching evaluation score, on a scale of 1 (very unsatisfactory) to 5 (excellent).                                                    |
# | division    | Is the course an upper or lower division course?                                                                                                     |
# | native      | Is the instructor a native English speaker?                                                                                                          |
# | tenure      | Is the instructor on a tenure track?                                                                                                                 |
# | students    | Number of students that participated in the evaluation.                                                                                              |
# | allstudents | Number of students enrolled in the course.                                                                                                           |
# | prof        | Indicating instructor identifier.                                                                                                                    |

# %%
ratings_path = 'data/teachingratings.csv'
ratings_df = pd.read_csv(ratings_path)
ratings_df
# Out:
#     minority  age  gender credits    beauty  eval division native tenure  \
# 0        yes   36  female    more  0.289916   4.3    upper    yes    yes
# 1        yes   36  female    more  0.289916   3.7    upper    yes    yes
# 2        yes   36  female    more  0.289916   3.6    upper    yes    yes
# 3        yes   36  female    more  0.289916   4.4    upper    yes    yes
# 4         no   59    male    more -0.737732   4.5    upper    yes    yes
# ..       ...  ...     ...     ...       ...   ...      ...    ...    ...
# 458       no   37    male    more  0.933396   3.5    upper    yes    yes
# 459       no   58  female    more  0.111563   3.5    upper    yes    yes
# 460       no   42    male    more -0.900580   4.0    upper    yes    yes
# 461       no   39    male    more  0.643014   4.3    upper    yes    yes
# 462       no   51  female    more  0.391822   3.0    upper    yes    yes
#
#      students  allstudents  prof  PrimaryLast  vismin  female  single_credit  \
# ...

# %% [markdown]
# ### Find the mean, median, minimum, and maximum values for students

# %%
# your code here
print(ratings_df.students.mean())
print(ratings_df.students.median())
print(ratings_df.students.min())
print(ratings_df.students.max())
student_stats = ratings_df.students.agg(['mean', 'median', 'min', 'max'])
display(student_stats)
# Out:
# 36.62419006479482
# 23.0
# 5
# 380
# mean       36.62419
# median     23.00000
# min         5.00000
# max       380.00000
# Name: students, dtype: float64

# %% [markdown]
# ### Produce a descriptive statistics table

# %%
# your code here
display(ratings_df.describe())
# Out:
#               age        beauty        eval    students  allstudents  \
# count  463.000000  4.630000e+02  463.000000  463.000000   463.000000
# mean    48.365011  6.271140e-08    3.998272   36.624190    55.177106
# std      9.802742  7.886477e-01    0.554866   45.018481    75.072800
# min     29.000000 -1.450494e+00    2.100000    5.000000     8.000000
# 25%     42.000000 -6.562689e-01    3.600000   15.000000    19.000000
# 50%     48.000000 -6.801430e-02    4.000000   23.000000    29.000000
# 75%     57.000000  5.456024e-01    4.400000   40.000000    60.000000
# max     73.000000  1.970023e+00    5.000000  380.000000   581.000000
#
#              prof  PrimaryLast      vismin      female  single_credit  \
# count  463.000000   463.000000  463.000000  463.000000     463.000000
# mean    45.434125     0.203024    0.138229    0.421166       0.058315
# std     27.508902     0.402685    0.345513    0.494280       0.234592
# ...

# %% [markdown]
# ### Create a histogram of the beauty variable and briefly comment on the distribution of data

# %%
# your code here
ratings_df.beauty.hist(bins=20)
# slightly right-skewed distribution
# Out:
# <Axes: >

# %% [markdown]
# ### Does average beauty score differ by gender? Produce the means and standard deviations for both male and female instructors.

# %%
# your code here
print(ratings_df.beauty[ratings_df['gender']=='male'].mean())
print(ratings_df.beauty[ratings_df['gender']=='male'].std())
print(ratings_df.beauty[ratings_df['gender']=='female'].mean())
print(ratings_df.beauty[ratings_df['gender']=='female'].std())

beauty_stats = ratings_df.groupby('gender')['beauty'].agg(['mean', 'std'])
display(beauty_stats)
# Out:
# -0.084482238273512
# 0.7571299272149642
# 0.11610907124450924
# 0.8178096472554823
#             mean      std
# gender
# female  0.116109  0.81781
# male   -0.084482  0.75713

# %% [markdown]
# ### Does average age differ by tenure? Produce the means and standard deviations for both tenured and untenured professors.

# %%
# your code here
prof_stats = ratings_df.groupby('tenured_prof')['age'].agg(['mean', 'std'])
display(prof_stats)
# Out:
#                    mean        std
# tenured_prof
# 0             50.186275   6.946372
# 1             47.850416  10.420056

# %% [markdown]
# ### Create a histogram for the age variable.

# %%
# your code here
ratings_df.age.hist(bins=20)
# approximately normal distribution with slight right skew
# Out:
# <Axes: >

# %% [markdown]
# ### Question 4: What is the Median evaluation score for tenured Professors?

# %%
# median evaluation score for tenured professors
ratings_df.loc[ratings_df['tenured_prof'] == 1, 'eval'].median()
# Out:
# np.float64(4.0)
